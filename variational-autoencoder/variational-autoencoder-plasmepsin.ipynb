# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"></ul></div>

# %%
import warnings
import msmexplorer as msme
warnings.filterwarnings('ignore')
import seaborn as sns
# %pylab inline
import numpy as np
import os 
import pandas as pd
import mdtraj as md 
sns.set_style("whitegrid")
sns.set_context("talk",1.3)
from msmbuilder.utils import load,dump
# Out:
# /home/sbhakat/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# /home/sbhakat/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)
# /home/sbhakat/miniconda2/envs/py36/lib/python3.6/site-packages/seaborn/apionly.py:9: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)
# /home/sbhakat/miniconda2/envs/py36/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# Populating the interactive namespace from numpy and matplotlib

# %%
feat = load("/home/sbhakat/Plm-TICA-TIP4P-MD/Res-69-91/featurizer.pkl")

# %%
df = pd.read_pickle("/home/sbhakat/Plm-TICA-TIP4P-MD/Res-69-91/feature_descriptor.pkl")

# %%
df
# Out:
#                 atominds featuregroup featurizer otherinfo resids resnames  \
# 0       [14, 16, 18, 21]         chi1   Dihedral       sin   [69]    [LYS]
# 1       [36, 38, 40, 43]         chi1   Dihedral       sin   [70]    [ASP]
# 2       [55, 57, 59, 65]         chi1   Dihedral       sin   [72]    [THR]
# 3       [69, 71, 73, 76]         chi1   Dihedral       sin   [73]    [LYS]
# 4       [91, 93, 95, 97]         chi1   Dihedral       sin   [74]    [VAL]
# 5   [107, 109, 111, 114]         chi1   Dihedral       sin   [75]    [GLU]
# 6   [122, 124, 126, 129]         chi1   Dihedral       sin   [76]    [MET]
# 7   [139, 141, 143, 146]         chi1   Dihedral       sin   [77]    [ASN]
# 8   [153, 155, 157, 160]         chi1   Dihedral       sin   [78]    [TYR]
# 9   [174, 176, 178, 180]         chi1   Dihedral       sin   [79]    [VAL]
# 10  [190, 192, 194, 197]         chi1   Dihedral       sin   [80]    [SER]
# 11  [208, 210, 212, 218]         chi1   Dihedral       sin   [82]    [THR]
# 12  [222, 224, 226, 228]         chi1   Dihedral       sin   [83]    [VAL]
# 13  [238, 240, 242, 245]         chi1   Dihedral       sin   [84]    [SER]
# 14  [256, 258, 260, 263]         chi1   Dihedral       sin   [86]    [PHE]
# 15  [276, 278, 280, 283]         chi1   Dihedral       sin   [87]    [PHE]
# 16  [296, 298, 300, 303]         chi1   Dihedral       sin   [88]    [SER]
# 17  [307, 309, 311, 314]         chi1   Dihedral       sin   [89]    [LYS]
# 18      [14, 16, 18, 21]         chi1   Dihedral       cos   [69]    [LYS]
# 19      [36, 38, 40, 43]         chi1   Dihedral       cos   [70]    [ASP]
# 20      [55, 57, 59, 65]         chi1   Dihedral       cos   [72]    [THR]
# 21      [69, 71, 73, 76]         chi1   Dihedral       cos   [73]    [LYS]
# 22      [91, 93, 95, 97]         chi1   Dihedral       cos   [74]    [VAL]
# 23  [107, 109, 111, 114]         chi1   Dihedral       cos   [75]    [GLU]
# 24  [122, 124, 126, 129]         chi1   Dihedral       cos   [76]    [MET]
# 25  [139, 141, 143, 146]         chi1   Dihedral       cos   [77]    [ASN]
# 26  [153, 155, 157, 160]         chi1   Dihedral       cos   [78]    [TYR]
# 27  [174, 176, 178, 180]         chi1   Dihedral       cos   [79]    [VAL]
# 28  [190, 192, 194, 197]         chi1   Dihedral       cos   [80]    [SER]
# 29  [208, 210, 212, 218]         chi1   Dihedral       cos   [82]    [THR]
# 30  [222, 224, 226, 228]         chi1   Dihedral       cos   [83]    [VAL]
# 31  [238, 240, 242, 245]         chi1   Dihedral       cos   [84]    [SER]
# 32  [256, 258, 260, 263]         chi1   Dihedral       cos   [86]    [PHE]
# 33  [276, 278, 280, 283]         chi1   Dihedral       cos   [87]    [PHE]
# 34  [296, 298, 300, 303]         chi1   Dihedral       cos   [88]    [SER]
# 35  [307, 309, 311, 314]         chi1   Dihedral       cos   [89]    [LYS]
# 36          [1, 3, 6, 9]         chi2   Dihedral       sin   [68]    [GLU]
# 37      [16, 18, 21, 24]         chi2   Dihedral       sin   [69]    [LYS]
# 38      [38, 40, 43, 44]         chi2   Dihedral       sin   [70]    [ASP]
# 39      [71, 73, 76, 79]         chi2   Dihedral       sin   [73]    [LYS]
# 40  [109, 111, 114, 117]         chi2   Dihedral       sin   [75]    [GLU]
# 41  [124, 126, 129, 132]         chi2   Dihedral       sin   [76]    [MET]
# 42  [141, 143, 146, 147]         chi2   Dihedral       sin   [77]    [ASN]
# 43  [155, 157, 160, 161]         chi2   Dihedral       sin   [78]    [TYR]
# 44  [258, 260, 263, 264]         chi2   Dihedral       sin   [86]    [PHE]
# 45  [278, 280, 283, 284]         chi2   Dihedral       sin   [87]    [PHE]
# 46  [309, 311, 314, 317]         chi2   Dihedral       sin   [89]    [LYS]
# 47          [1, 3, 6, 9]         chi2   Dihedral       cos   [68]    [GLU]
# 48      [16, 18, 21, 24]         chi2   Dihedral       cos   [69]    [LYS]
# 49      [38, 40, 43, 44]         chi2   Dihedral       cos   [70]    [ASP]
# 50      [71, 73, 76, 79]         chi2   Dihedral       cos   [73]    [LYS]
# 51  [109, 111, 114, 117]         chi2   Dihedral       cos   [75]    [GLU]
# 52  [124, 126, 129, 132]         chi2   Dihedral       cos   [76]    [MET]
# 53  [141, 143, 146, 147]         chi2   Dihedral       cos   [77]    [ASN]
# 54  [155, 157, 160, 161]         chi2   Dihedral       cos   [78]    [TYR]
# 55  [258, 260, 263, 264]         chi2   Dihedral       cos   [86]    [PHE]
# 56  [278, 280, 283, 284]         chi2   Dihedral       cos   [87]    [PHE]
# 57  [309, 311, 314, 317]         chi2   Dihedral       cos   [89]    [LYS]
#
#    resseqs
# 0     [70]
# 1     [71]
# 2     [73]
# 3     [74]
# 4     [75]
# 5     [76]
# 6     [77]
# 7     [78]
# 8     [79]
# 9     [80]
# 10    [81]
# 11    [83]
# 12    [84]
# 13    [85]
# 14    [87]
# 15    [88]
# 16    [89]
# 17    [90]
# 18    [70]
# 19    [71]
# 20    [73]
# 21    [74]
# 22    [75]
# 23    [76]
# 24    [77]
# 25    [78]
# 26    [79]
# 27    [80]
# 28    [81]
# 29    [83]
# 30    [84]
# 31    [85]
# 32    [87]
# 33    [88]
# 34    [89]
# 35    [90]
# 36    [69]
# 37    [70]
# 38    [71]
# 39    [74]
# 40    [76]
# 41    [77]
# 42    [78]
# 43    [79]
# 44    [87]
# 45    [88]
# 46    [90]
# 47    [69]
# 48    [70]
# 49    [71]
# 50    [74]
# 51    [76]
# 52    [77]
# 53    [78]
# 54    [79]
# 55    [87]
# 56    [88]
# 57    [90]

# %%
tica_mdl =load("/home/sbhakat/Plm-TICA-TIP4P-MD/Res-69-91/tica_mdl_flapchi1angle.pkl")

# %%
tica_mdl
# Out:
# tICA(commute_mapping=False, kinetic_mapping=False, lag_time=10, n_components=5,
#      shrinkage=None)

# %%
plot(tica_mdl.components_[0])
plot(tica_mdl.components_[1])

# %%
plot(tica_mdl.timescales_)

# %%
tica_data = load("/home/sbhakat/Plm-TICA-TIP4P-MD/Res-69-91/tica_data.pkl")

# %%
import torch
from vde import VDE

# %%
# %matplotlib inline
import msmexplorer as msme
import numpy as np
txx = np.concatenate(tica_data)
_ = msme.plot_histogram(txx)

# %%
model = VDE(2,lag_time=25,hidden_layer_depth=2,hidden_size=20,n_epochs=100,batch_size=400,learning_rate=1e-2)
model.dtype = torch.DoubleTensor
model.use_cuda =False
model.cpu()
model.double()
model.fit(tica_data)
torch.save(model,"trained_plm.pkl")
# Out:
# Epoch: 0
# Batch 100, loss = 0.9527
# rec_loss = 0.9467, autocorr_loss = 0.0059
# Epoch: 1
# Batch 100, loss = 0.5083
# rec_loss = 0.5011, autocorr_loss = 0.0072
# Epoch: 2
# Batch 100, loss = 0.2300
# rec_loss = 0.2227, autocorr_loss = 0.0073
# Epoch: 3
# Batch 100, loss = 0.1769
# rec_loss = 0.1590, autocorr_loss = 0.0179
# Epoch: 4
# Batch 100, loss = 0.1434
# rec_loss = 0.1365, autocorr_loss = 0.0069
# Epoch: 5
# Batch 100, loss = 0.1441
# rec_loss = 0.1376, autocorr_loss = 0.0065
# Epoch: 6
# Batch 100, loss = 0.1795
# rec_loss = 0.1661, autocorr_loss = 0.0134
# Epoch: 7
# Batch 100, loss = 0.1758
# rec_loss = 0.1573, autocorr_loss = 0.0185
# Epoch: 8
# Batch 100, loss = 0.1477
# rec_loss = 0.1406, autocorr_loss = 0.0071
# Epoch: 9
# Batch 100, loss = 0.1238
# rec_loss = 0.1158, autocorr_loss = 0.0080
# Epoch: 10
# Batch 100, loss = 0.1526
# rec_loss = 0.1440, autocorr_loss = 0.0086
# Epoch: 11
# Batch 100, loss = 0.1620
# rec_loss = 0.1536, autocorr_loss = 0.0084
# Epoch: 12
# Batch 100, loss = 0.1327
# rec_loss = 0.1203, autocorr_loss = 0.0124
# Epoch: 13
# Batch 100, loss = 0.1248
# rec_loss = 0.1166, autocorr_loss = 0.0082
# Epoch: 14
# Batch 100, loss = 0.1476
# rec_loss = 0.1340, autocorr_loss = 0.0137
# Epoch: 15
# Batch 100, loss = 0.1314
# rec_loss = 0.1177, autocorr_loss = 0.0138
# Epoch: 16
# Batch 100, loss = 0.1405
# rec_loss = 0.1296, autocorr_loss = 0.0109
# Epoch: 17
# Batch 100, loss = 0.1161
# rec_loss = 0.1132, autocorr_loss = 0.0028
# Epoch: 18
# Batch 100, loss = 0.1306
# rec_loss = 0.1131, autocorr_loss = 0.0174
# Epoch: 19
# Batch 100, loss = 0.1059
# rec_loss = 0.1023, autocorr_loss = 0.0036
# Epoch: 20
# Batch 100, loss = 0.1129
# rec_loss = 0.1092, autocorr_loss = 0.0036
# Epoch: 21
# Batch 100, loss = 0.1013
# rec_loss = 0.0966, autocorr_loss = 0.0046
# Epoch: 22
# Batch 100, loss = 0.1087
# rec_loss = 0.0934, autocorr_loss = 0.0153
# Epoch: 23
# Batch 100, loss = 0.1524
# rec_loss = 0.1212, autocorr_loss = 0.0312
# Epoch: 24
# Batch 100, loss = 0.1039
# rec_loss = 0.0958, autocorr_loss = 0.0081
# Epoch: 25
# Batch 100, loss = 0.1085
# rec_loss = 0.1034, autocorr_loss = 0.0051
# Epoch: 26
# Batch 100, loss = 0.0947
# rec_loss = 0.0879, autocorr_loss = 0.0068
# Epoch: 27
# Batch 100, loss = 0.1068
# rec_loss = 0.0912, autocorr_loss = 0.0156
# Epoch: 28
# Batch 100, loss = 0.1062
# rec_loss = 0.0966, autocorr_loss = 0.0097
# Epoch: 29
# Batch 100, loss = 0.1175
# rec_loss = 0.1073, autocorr_loss = 0.0102
# Epoch: 30
# Batch 100, loss = 0.1445
# rec_loss = 0.1148, autocorr_loss = 0.0297
# Epoch: 31
# Batch 100, loss = 0.0938
# rec_loss = 0.0886, autocorr_loss = 0.0052
# Epoch: 32
# Batch 100, loss = 0.1037
# rec_loss = 0.0919, autocorr_loss = 0.0118
# Epoch: 33
# Batch 100, loss = 0.1159
# rec_loss = 0.1095, autocorr_loss = 0.0064
# Epoch: 34
# Batch 100, loss = 0.0851
# rec_loss = 0.0821, autocorr_loss = 0.0030
# Epoch: 35
# Batch 100, loss = 0.1313
# rec_loss = 0.1223, autocorr_loss = 0.0090
# Epoch: 36
# Batch 100, loss = 0.1135
# rec_loss = 0.0971, autocorr_loss = 0.0164
# Epoch: 37
# Batch 100, loss = 0.1032
# rec_loss = 0.0944, autocorr_loss = 0.0088
# Epoch: 38
# Batch 100, loss = 0.0911
# rec_loss = 0.0809, autocorr_loss = 0.0102
# Epoch: 39
# Batch 100, loss = 0.0989
# rec_loss = 0.0952, autocorr_loss = 0.0037
# Epoch: 40
# Batch 100, loss = 0.1103
# rec_loss = 0.0939, autocorr_loss = 0.0163
# Epoch: 41
# Batch 100, loss = 0.0861
# rec_loss = 0.0834, autocorr_loss = 0.0027
# Epoch: 42
# Batch 100, loss = 0.0794
# rec_loss = 0.0738, autocorr_loss = 0.0055
# Epoch: 43
# Batch 100, loss = 0.0931
# rec_loss = 0.0717, autocorr_loss = 0.0214
# Epoch: 44
# Batch 100, loss = 0.1009
# rec_loss = 0.0940, autocorr_loss = 0.0069
# Epoch: 45
# Batch 100, loss = 0.0815
# rec_loss = 0.0776, autocorr_loss = 0.0039
# Epoch: 46
# Batch 100, loss = 0.0769
# rec_loss = 0.0654, autocorr_loss = 0.0115
# Epoch: 47
# Batch 100, loss = 0.0785
# rec_loss = 0.0657, autocorr_loss = 0.0128
# Epoch: 48
# Batch 100, loss = 0.1052
# rec_loss = 0.1007, autocorr_loss = 0.0045
# Epoch: 49
# Batch 100, loss = 0.0924
# rec_loss = 0.0874, autocorr_loss = 0.0050
# Epoch: 50
# Batch 100, loss = 0.1697
# rec_loss = 0.1638, autocorr_loss = 0.0059
# Epoch: 51
# Batch 100, loss = 0.0872
# rec_loss = 0.0833, autocorr_loss = 0.0039
# Epoch: 52
# Batch 100, loss = 0.1007
# rec_loss = 0.0985, autocorr_loss = 0.0022
# Epoch: 53
# Batch 100, loss = 0.1077
# rec_loss = 0.0924, autocorr_loss = 0.0152
# Epoch: 54
# Batch 100, loss = 0.0829
# rec_loss = 0.0781, autocorr_loss = 0.0049
# Epoch: 55
# Batch 100, loss = 0.1258
# rec_loss = 0.1055, autocorr_loss = 0.0203
# Epoch: 56
# Batch 100, loss = 0.1212
# rec_loss = 0.0812, autocorr_loss = 0.0400
# Epoch: 57
# Batch 100, loss = 0.1158
# rec_loss = 0.1072, autocorr_loss = 0.0087
# Epoch: 58
# Batch 100, loss = 0.1120
# rec_loss = 0.0972, autocorr_loss = 0.0149
# Epoch: 59
# Batch 100, loss = 0.1018
# rec_loss = 0.0844, autocorr_loss = 0.0174
# Epoch: 60
# Batch 100, loss = 0.0955
# rec_loss = 0.0905, autocorr_loss = 0.0049
# Epoch: 61
# Batch 100, loss = 0.0852
# rec_loss = 0.0682, autocorr_loss = 0.0170
# Epoch: 62
# Batch 100, loss = 0.0724
# rec_loss = 0.0685, autocorr_loss = 0.0039
# Epoch: 63
# Batch 100, loss = 0.1114
# rec_loss = 0.0900, autocorr_loss = 0.0214
# Epoch: 64
# Batch 100, loss = 0.0837
# rec_loss = 0.0775, autocorr_loss = 0.0062
# Epoch: 65
# Batch 100, loss = 0.0832
# rec_loss = 0.0762, autocorr_loss = 0.0069
# Epoch: 66
# Batch 100, loss = 0.0826
# rec_loss = 0.0702, autocorr_loss = 0.0125
# Epoch: 67
# Batch 100, loss = 0.0830
# rec_loss = 0.0639, autocorr_loss = 0.0191
# Epoch: 68
# Batch 100, loss = 0.0994
# rec_loss = 0.0924, autocorr_loss = 0.0070
# Epoch: 69
# Batch 100, loss = 0.0958
# rec_loss = 0.0827, autocorr_loss = 0.0131
# Epoch: 70
# Batch 100, loss = 0.0709
# rec_loss = 0.0689, autocorr_loss = 0.0020
# Epoch: 71
# Batch 100, loss = 0.0865
# rec_loss = 0.0728, autocorr_loss = 0.0137
# Epoch: 72
# Batch 100, loss = 0.0957
# rec_loss = 0.0833, autocorr_loss = 0.0124
# Epoch: 73
# Batch 100, loss = 0.0855
# rec_loss = 0.0811, autocorr_loss = 0.0044
# Epoch: 74
# Batch 100, loss = 0.0827
# rec_loss = 0.0782, autocorr_loss = 0.0045
# Epoch: 75
# Batch 100, loss = 0.0728
# rec_loss = 0.0640, autocorr_loss = 0.0089
# Epoch: 76
# Batch 100, loss = 0.0785
# rec_loss = 0.0749, autocorr_loss = 0.0035
# Epoch: 77
# Batch 100, loss = 0.0916
# rec_loss = 0.0883, autocorr_loss = 0.0033
# Epoch: 78
# Batch 100, loss = 0.0915
# rec_loss = 0.0882, autocorr_loss = 0.0033
# Epoch: 79
# Batch 100, loss = 0.0853
# rec_loss = 0.0734, autocorr_loss = 0.0119
# Epoch: 80
# Batch 100, loss = 0.0865
# rec_loss = 0.0834, autocorr_loss = 0.0032
# Epoch: 81
# Batch 100, loss = 0.0688
# rec_loss = 0.0641, autocorr_loss = 0.0047
# Epoch: 82
# Batch 100, loss = 0.0890
# rec_loss = 0.0767, autocorr_loss = 0.0123
# Epoch: 83
# Batch 100, loss = 0.0694
# rec_loss = 0.0659, autocorr_loss = 0.0035
# Epoch: 84
# Batch 100, loss = 0.0720
# rec_loss = 0.0678, autocorr_loss = 0.0041
# Epoch: 85
# Batch 100, loss = 0.0691
# rec_loss = 0.0658, autocorr_loss = 0.0033
# Epoch: 86
# Batch 100, loss = 0.0838
# rec_loss = 0.0704, autocorr_loss = 0.0133
# Epoch: 87
# Batch 100, loss = 0.0797
# rec_loss = 0.0687, autocorr_loss = 0.0110
# Epoch: 88
# Batch 100, loss = 0.1010
# rec_loss = 0.0682, autocorr_loss = 0.0328
# Epoch: 89
# Batch 100, loss = 0.0868
# rec_loss = 0.0841, autocorr_loss = 0.0027
# Epoch: 90
# Batch 100, loss = 0.0858
# rec_loss = 0.0795, autocorr_loss = 0.0063
# Epoch: 91
# Batch 100, loss = 0.0903
# rec_loss = 0.0811, autocorr_loss = 0.0092
# Epoch: 92
# Batch 100, loss = 0.0808
# rec_loss = 0.0762, autocorr_loss = 0.0046
# Epoch: 93
# Batch 100, loss = 0.0998
# rec_loss = 0.0874, autocorr_loss = 0.0125
# Epoch: 94
# Batch 100, loss = 0.0855
# rec_loss = 0.0795, autocorr_loss = 0.0060
# Epoch: 95
# Batch 100, loss = 0.0872
# rec_loss = 0.0834, autocorr_loss = 0.0038
# Epoch: 96
# Batch 100, loss = 0.0871
# rec_loss = 0.0771, autocorr_loss = 0.0101
# Epoch: 97
# Batch 100, loss = 0.1177
# rec_loss = 0.0988, autocorr_loss = 0.0189
# Epoch: 98
# Batch 100, loss = 0.0626
# rec_loss = 0.0598, autocorr_loss = 0.0029
# Epoch: 99
# Batch 100, loss = 0.0887
# rec_loss = 0.0787, autocorr_loss = 0.0100

# %%
model = torch.load("trained_plm.pkl")

# %%
from torch.autograd import Variable

# %%
plt.rcParams["figure.figsize"] = (20,10)
model.eval()
X=Variable(torch.from_numpy(txx[:,:model.input_size]).type(model.dtype))
output = model.encoder.output_layer(model.encoder.hidden_network(model.encoder.input_layer(X))).cpu().data.numpy()
p=scatter(txx[:,0],txx[:,1],c=np.squeeze(output),cmap='viridis')
xlabel("TIC 1")
ylabel("TIC 2")
cb=colorbar(p,orientation="vertical")
cb.set_label("Bottleneck layer (z)")

# %%
msme.plot_free_energy(output,gridsize=200)
ylim([0,10])
xlabel("Bottleneck layer (z)")
ylabel("Free Energy")
# Out:
# Text(0, 0.5, 'Free Energy')

# %%
plt.rcParams["figure.figsize"] = (20,10)
msme.plot_free_energy(txx, obs=(0, 1), n_samples=100000,
                      xlabel='TIC1', ylabel='TIC2')

# %%
msme.plot_free_energy(txx, obs=(0), n_samples=100000,gridsize=200)
ylim([0,6])
xlabel("TIC1")
ylabel("Free Energy")
# Out:
# Text(0, 0.5, 'Free Energy')
